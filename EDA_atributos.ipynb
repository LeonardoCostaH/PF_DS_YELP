# %% [markdown]
# # Import globales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Lectura  archivos

# %%
df_atributos_alabama = pd.read_csv("files/data/booking/attributes/alabama_hotels_attributes.csv")
df_atributos_arizona = pd.read_csv("files/data/booking/attributes/arizona_hotels_attributes.csv")
df_atributos_california = pd.read_csv("files/data/booking/attributes/california_hotels_attributes.csv")
df_atributos_florida = pd.read_csv("files/data/booking/attributes/florida_hotels_attributes.csv")
df_atributos_georgia = pd.read_csv("files/data/booking/attributes/georgia_hotels_attributes.csv")
df_atributos_nevada = pd.read_csv("files/data/booking/attributes/nevada_hotels_attributes.csv")

# %% [markdown]
# # Analisis General

# %% [markdown]
# ## Analisis de atributos Alabama

# %%
df_atributos_alabama.shape
# Out:
# (1344, 7)

# %%
df_atributos_alabama.head()
# Out:
#    hotel_id                                          direction  \
# 0       108  25 Via del Giardino Serristori, 50125 Florenci...
# 1       114  5 Borgo San Jacopo, Santo Spirito, 50125 Flore...
# 2       119  via dei Rustici 1A, Uffizi, 50122 Florencia, I...
# 3       346  9 Via Vincenzo Borghini, Campo di Marte, 50133...
# 4       354  7 Piazza della Signoria, Uffizi, 50122 Florenc...
#
#                                          description  \
# 0  El S2 - Tower se encuentra en el centro de Flo...
# 1  L'Angolo di Ponte Vecchio se encuentra en el c...
# 2  La Casa S a f e r ofrece alojamiento a 500 met...
# 3  El The Place to Be! In Florence close to the c...
# 4  El Signoria Deluxe Studio-2 people in Signoria...
#
#                                           attributes   latitude  longitude  \
# 0                                                NaN  43.764761  11.261114
# 1  ['Aire acondicionado', 'Calefacción', 'Mesa de...  43.767622  11.252144
# ...

# %%
df_atributos_alabama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     1344 non-null   int64
#  1   direction    1344 non-null   object
#  2   description  1171 non-null   object
#  3   attributes   974 non-null    object
#  4   latitude     1344 non-null   float64
#  5   longitude    1344 non-null   float64
#  6   scores       726 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 73.6+ KB

# %%
df_atributos_alabama.describe()
# Out:
#            hotel_id     latitude    longitude
# count   1344.000000  1344.000000  1344.000000
# mean   23368.012649    43.473608   -18.461217
# std    12291.768045     7.363235    41.242071
# min      108.000000    30.585567   -88.222452
# 25%    13020.500000    34.737203   -85.430841
# 50%    23612.500000    43.773331    -1.874829
# 75%    34027.500000    52.454843    11.252263
# max    43220.000000    52.587760    11.315314

# %%
df_atributos_alabama.columns
# Out:
# Index(['hotel_id', 'direction', 'description', 'attributes', 'latitude',
#        'longitude', 'scores'],
#       dtype='object')

# %%
df_atributos_alabama['direction'].value_counts()
# Out:
# direction
# Tuscaloosa, 35401, Estados Unidos                                          12
# Carlyle Road 66, Edgbaston, Birmingham, B16 9BJ, Reino Unido                6
# 1 Mint Drive, Birmingham, B18 6EA, Reino Unido                              6
# Auburn, 36832, Estados Unidos                                               4
# Halfords Lane, Birmingham, B66 1BB, Reino Unido                             4
#                                                                            ..
# 24 Francis rd Broardway plaza, Birmingham, B16 8SU, Reino Unido             1
# 824 West I-65 Service Road South, Mobile, AL 36609-1302, Estados Unidos     1
# 3920 McFarland Blvd E, Tuscaloosa, 35405-2406, Estados Unidos               1
# Via Nazionale 22, San Lorenzo, 50123 Florencia, Italia                      1
# 15 Wanderer Walk, Birmingham, B36 8SW, Reino Unido                          1
# Name: count, Length: 1178, dtype: int64

# %%
df_atributos_alabama.isnull().sum()
# Out:
# hotel_id         0
# direction        0
# description    173
# attributes     370
# latitude         0
# longitude        0
# scores         618
# dtype: int64

# %%
df_atributos_alabama['attributes']
# Out:
# 0                                                     NaN
# 1       ['Aire acondicionado', 'Calefacción', 'Mesa de...
# 2                                                     NaN
# 3                                                     NaN
# 4       ['¿Puedo llevar a mi mascota?', '¿Cuál es el h...
#                               ...
# 1339    ['Parking gratis', 'Secadora de ropa', 'WiFi g...
# 1340    ['¿Se sirven desayunos?', 'Parking gratis', '¿...
# 1341    ['Parking gratis', 'Secadora de ropa', 'Microo...
# 1342    ['¿Se sirven desayunos?', 'Parking gratis', '¿...
# 1343    ['Parking gratis', 'Adaptado personas de movil...
# Name: attributes, Length: 1344, dtype: object

# %%
df_atributos_alabama['description']
# Out:
# 0       El S2 - Tower se encuentra en el centro de Flo...
# 1       L'Angolo di Ponte Vecchio se encuentra en el c...
# 2       La Casa S a f e r ofrece alojamiento a 500 met...
# 3       El The Place to Be! In Florence close to the c...
# 4       El Signoria Deluxe Studio-2 people in Signoria...
#                               ...
# 1339    Located in Huntsville, 8.3 km from Southern Ad...
# 1340    El Cheerful Specious Home se encuentra en Hunt...
# 1341    El Pluxa Opal Luxury se encuentra en el centro...
# 1342    El New Spacious Entire Home + Parking by Real ...
# 1343    El Alpha House by Night Stay: Contractors Slee...
# Name: description, Length: 1344, dtype: object

# %%
df_atributos_alabama['scores'].tolist()
# Out:
# ["[{'Estudio con vistas al jardín': '1 cama doble grande'}]",
#  "[{'Apartamento de 1 dormitorio': '1 cama doble extragrande'}]",
#  nan,
#  '[]',
#  "[{'Apartamento de 1 dormitorio': '1 cama doble'}]",
#  '[]',
#  "[{'Personal': '9.5'}, {'Instalaciones y servicios': '10'}, {'Limpieza': '10'}, {'Confort': '10'}, {'Relación calidad-precio': '10'}, {'Ubicación': '10'}]",
#  nan,
#  nan,
#  "[{'Apartamento de 1 dormitorio': '1 cama doble grande'}]",
# ...

# %% [markdown]
# ## Datos nulos

# %%
import seaborn as sns

sns.heatmap(df_atributos_alabama.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atri_clear=df_atributos_alabama.copy()

# %%
df_atri_clear[df_atri_clear['description'].isnull()]
# Out:
#       hotel_id                                          direction description  \
# 6          727   3 Via dei Pecori, Duomo, 50123 Florencia, Italia         NaN
# 19        2181         Via San Zanobi 86, 50129 Florencia, Italia         NaN
# 20        2227  1182 Northlake Drive, Auburn, AL 36832, Estado...         NaN
# 31        2562  44 Via del Leone, San Frediano, 50124 Florenci...         NaN
# 33        2572  Via dell'Albero, Santa María Novella, 50123 Fl...         NaN
# ...        ...                                                ...         ...
# 1317     42969     5 Vere Street, Birmingham, B5 7FS, Reino Unido         NaN
# 1318     42982                   Birmingham, B66 3DN, Reino Unido         NaN
# 1328     43095                  Tuscaloosa, 35401, Estados Unidos         NaN
# 1329     43124                  Tuscaloosa, 35401, Estados Unidos         NaN
# 1330     43127                  Tuscaloosa, 35401, Estados Unidos         NaN
#
# ...

# %%
df_atri_clear[df_atri_clear['attributes'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 0          108  25 Via del Giardino Serristori, 50125 Florenci...
# 2          119  via dei Rustici 1A, Uffizi, 50122 Florencia, I...
# 3          346  9 Via Vincenzo Borghini, Campo di Marte, 50133...
# 8         1062                      Auburn, 36832, Estados Unidos
# 9         1121  1 Via de' Barbadori, Santo Spirito, 50125 Flor...
# ...        ...                                                ...
# 1313     42939  Carlyle Road 66, Edgbaston, Birmingham, B16 9B...
# 1315     42954  Essex Street, Gay Village Birmingham, Birmingh...
# 1316     42960   Scotland Street, Birmingham, B1 2AU, Reino Unido
# 1334     43150  14 Wheeleys Lane, Birmingham, B15 2DG, Reino U...
# 1337     43172    Somerset Road, Birmingham, B23 6NG, Reino Unido
#
#                                             description attributes   latitude  \
# 0     El S2 - Tower se encuentra en el centro de Flo...        NaN  43.764761
# ...

# %%
df_atri_clear[df_atri_clear['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 2          119  via dei Rustici 1A, Uffizi, 50122 Florencia, I...
# 7         1048                      Auburn, 36832, Estados Unidos
# 8         1062                      Auburn, 36832, Estados Unidos
# 13        1243                  Birmingham, 35203, Estados Unidos
# 17        2137        12 Via Colleramole, 50023 Florencia, Italia
# ...        ...                                                ...
# 1331     43131                    Birmingham, B1 3ER, Reino Unido
# 1333     43147    Halfords Lane, Birmingham, B66 1BB, Reino Unido
# 1337     43172    Somerset Road, Birmingham, B23 6NG, Reino Unido
# 1338     43178  17 Rotton Park Rd, Edgbaston, Birmingham, B16 ...
# 1343     43220  15 Wanderer Walk, Birmingham, B36 8SW, Reino U...
#
#                                             description  \
# 2     La Casa S a f e r ofrece alojamiento a 500 met...
# 7     El Auburn Condo with 2 Pools Less Than 2 Mi to...
# ...

# %%
df_atri_clear[df_atri_clear['attributes'].isnull()&df_atri_clear['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 2          119  via dei Rustici 1A, Uffizi, 50122 Florencia, I...
# 8         1062                      Auburn, 36832, Estados Unidos
# 57        3910  90 Stockfield Road, Birmingham, B27 6BB, Reino...
# 59        4064  Moorcroft Drive 2916, Montgomery, 36116, Estad...
# 69        4627        34 Via Pietrapiana, 50121 Florencia, Italia
# ...        ...                                                ...
# 1207     40598  3141 University Drive Northwest, Huntsville, 3...
# 1215     40743                   Birmingham, B17 9JY, Reino Unido
# 1218     40772  Via del Presto 2, Uffizi, 50122 Florencia, Italia
# 1313     42939  Carlyle Road 66, Edgbaston, Birmingham, B16 9B...
# 1337     43172    Somerset Road, Birmingham, B23 6NG, Reino Unido
#
#                                             description attributes   latitude  \
# 2     La Casa S a f e r ofrece alojamiento a 500 met...        NaN  43.768554
# ...

# %%
df_atri_clear[df_atri_clear['description'].isnull()&df_atri_clear['scores'].isnull()]

# %% [markdown]
# ## Analsis de atributos Arizona

# %%
df_atributos_arizona.shape
# Out:
# (1277, 8)

# %%
df_atributos_arizona.head()
# Out:
#    Unnamed: 0  hotel_id                                          direction  \
# 0           0       NaN  1950 S Normandie Ave, , Los Ángeles, CA 90007,...
# 1           1       NaN  6250 Hollywood Boulevard, Hollywood, Los Ángel...
# 2           2       NaN  6001 West Third Street, Los Ángeles, CA 90036,...
# 3           3       NaN  1260 South Figueroa Street, Centro de Los Ánge...
# 4           4       NaN  837 N. Ridgewood Pl. #101, Hollywood, Los Ánge...
#
#                                          description  \
# 0  El Central Los Angeles Hollywood Homes es un a...
# 1  Este hotel boutique se encuentra en Hollywood,...
# 2  Este hotel se encuentra en el centro de la ciu...
# 3  El Moxy Downtown Los Angeles goza de una ubica...
# 4  El Hollywood Homes es un aparthotel sostenible...
#
#                                           attributes   latitude   longitude  \
# 0                                                NaN  34.038893 -118.300133
# ...

# %%
df_atributos_arizona = df_atributos_arizona.drop('Unnamed: 0', axis=1)

# %%
df_atributos_arizona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     0 non-null      float64
#  1   direction    1277 non-null   object
#  2   description  1259 non-null   object
#  3   attributes   1174 non-null   object
#  4   latitude     1277 non-null   float64
#  5   longitude    1277 non-null   float64
#  6   scores       1087 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 70.0+ KB

# %%
df_atributos_arizona.describe()
# Out:
#        hotel_id     latitude    longitude
# count       0.0  1277.000000  1277.000000
# mean        NaN    29.940136  -113.743841
# std         NaN    13.828717    14.085838
# min         NaN   -34.472918  -122.470386
# 25%         NaN    32.750120  -118.415121
# 50%         NaN    33.651016  -117.755660
# 75%         NaN    34.088668  -117.174932
# max         NaN    37.807763   -57.772451

# %%
df_atributos_arizona.columns
# Out:
# Index(['hotel_id', 'direction', 'description', 'attributes', 'latitude',
#        'longitude', 'scores'],
#       dtype='object')

# %%
df_atributos_arizona.isnull().sum()
# Out:
# hotel_id       1277
# direction         0
# description      18
# attributes      103
# latitude          0
# longitude         0
# scores          190
# dtype: int64

# %%
df_atributos_arizona['direction'].value_counts()
# Out:
# direction
# La Jolla, San Diego, 92037, Estados Unidos                                       31
# Mission Beach, San Diego, 92109, Estados Unidos                                  23
# Pacific Beach, San Diego, 92109, Estados Unidos                                  12
# 1860 Sixth Avenue, Centro de San Diego, San Diego, 92101, Estados Unidos         11
# 1811 Adams Avenue, San Diego, 92116, Estados Unidos                               8
#                                                                                  ..
# 1501 Lombard Street, Marina District, San Francisco, CA 94123, Estados Unidos     1
# 620 Post Street, Union Square, San Francisco, CA 94109, Estados Unidos            1
# 700 Eddy St , Tenderloin, San Francisco, 94109-7806, Estados Unidos               1
# 1650 Lombard Street, Marina District, San Francisco, CA 94123, Estados Unidos     1
# 1445 Sixth Avenue, Centro de San Diego, San Diego, 92101, Estados Unidos          1
# Name: count, Length: 1094, dtype: int64

# %% [markdown]
# ## Datos nulos

# %%
sns.heatmap(df_atributos_arizona.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atributos_arizona[df_atributos_arizona['attributes'].isnull()&df_atributos_arizona['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 0          NaN  1950 S Normandie Ave, , Los Ángeles, CA 90007,...
# 370        NaN  450 Post Street, Union Square, San Francisco, ...
# 373        NaN  2015 Greenwich Street, Marina District, San Fr...
# 549        NaN  550 J Street, Centro de San Diego, San Diego, ...
# 1000       NaN  750 metros sur de Fórum 1 , 10901 San José, Co...
#
#                                             description attributes   latitude  \
# 0     El Central Los Angeles Hollywood Homes es un a...        NaN  34.038893
# 370   Este hotel del centro de San Francisco, rodead...        NaN  37.788249
# 373   El Motel Capri se encuentra en el distrito de ...        NaN  37.799194
# 549   Pendry San Diego se encuentra en San Diego, a ...        NaN  32.709395
# 1000  El Studio Hotel ofrece una piscina en la azote...        NaN   9.934250
#
#        longitude scores
# 0    -118.300133    NaN
# 370  -122.409400    NaN
# ...

# %%
df_atributos_arizona[df_atributos_arizona['attributes'].isnull()&df_atributos_arizona['description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %%
df_atributos_arizona[df_atributos_arizona['scores'].isnull()&df_atributos_arizona['description'].isnull()]
# Out:
#      hotel_id                                          direction description  \
# 833       NaN  1261 Bluebird Lane, La Jolla, San Diego, 92037...         NaN
#
#                                             attributes   latitude   longitude  \
# 833  ['Parking gratis', 'Microondas', 'Lavadora', '...  32.843949 -117.269678
#
#     scores
# 833    NaN

# %%
df_atributos_arizona[df_atributos_arizona['scores'].isnull()&df_atributos_arizona['description'].isnull()&df_atributos_arizona['attributes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %% [markdown]
# ## Analisis de atributos Californa

# %%
df_atributos_california.shape
# Out:
# (1277, 8)

# %%
df_atributos_california.head()
# Out:
#    Unnamed: 0  hotel_id                                          direction  \
# 0           0       NaN  1950 S Normandie Ave, , Los Ángeles, CA 90007,...
# 1           1       NaN  6250 Hollywood Boulevard, Hollywood, Los Ángel...
# 2           2       NaN  6001 West Third Street, Los Ángeles, CA 90036,...
# 3           3       NaN  1260 South Figueroa Street, Centro de Los Ánge...
# 4           4       NaN  837 N. Ridgewood Pl. #101, Hollywood, Los Ánge...
#
#                                          description  \
# 0  El Central Los Angeles Hollywood Homes es un a...
# 1  Este hotel boutique se encuentra en Hollywood,...
# 2  Este hotel se encuentra en el centro de la ciu...
# 3  El Moxy Downtown Los Angeles goza de una ubica...
# 4  El Hollywood Homes es un aparthotel sostenible...
#
#                                           attributes   latitude   longitude  \
# 0                                                NaN  34.038893 -118.300133
# ...

# %%
df_atributos_california = df_atributos_california.drop('Unnamed: 0', axis=1)

# %%
df_atributos_california.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     0 non-null      float64
#  1   direction    1277 non-null   object
#  2   description  1259 non-null   object
#  3   attributes   1174 non-null   object
#  4   latitude     1277 non-null   float64
#  5   longitude    1277 non-null   float64
#  6   scores       1087 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 70.0+ KB

# %%
df_atributos_california.describe()
# Out:
#        hotel_id     latitude    longitude
# count       0.0  1277.000000  1277.000000
# mean        NaN    29.940136  -113.743841
# std         NaN    13.828717    14.085838
# min         NaN   -34.472918  -122.470386
# 25%         NaN    32.750120  -118.415121
# 50%         NaN    33.651016  -117.755660
# 75%         NaN    34.088668  -117.174932
# max         NaN    37.807763   -57.772451

# %%
df_atributos_arizona.columns
# Out:
# Index(['hotel_id', 'direction', 'description', 'attributes', 'latitude',
#        'longitude', 'scores'],
#       dtype='object')

# %%
df_atributos_california.isnull().sum()
# Out:
# hotel_id       1277
# direction         0
# description      18
# attributes      103
# latitude          0
# longitude         0
# scores          190
# dtype: int64

# %%
df_atributos_california['direction'].value_counts()
# Out:
# direction
# La Jolla, San Diego, 92037, Estados Unidos                                       31
# Mission Beach, San Diego, 92109, Estados Unidos                                  23
# Pacific Beach, San Diego, 92109, Estados Unidos                                  12
# 1860 Sixth Avenue, Centro de San Diego, San Diego, 92101, Estados Unidos         11
# 1811 Adams Avenue, San Diego, 92116, Estados Unidos                               8
#                                                                                  ..
# 1501 Lombard Street, Marina District, San Francisco, CA 94123, Estados Unidos     1
# 620 Post Street, Union Square, San Francisco, CA 94109, Estados Unidos            1
# 700 Eddy St , Tenderloin, San Francisco, 94109-7806, Estados Unidos               1
# 1650 Lombard Street, Marina District, San Francisco, CA 94123, Estados Unidos     1
# 1445 Sixth Avenue, Centro de San Diego, San Diego, 92101, Estados Unidos          1
# Name: count, Length: 1094, dtype: int64

# %% [markdown]
# ## DAtos nulos

# %%
sns.heatmap(df_atributos_california.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atributos_california[df_atributos_california['attributes'].isnull()&df_atributos_california['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 0          NaN  1950 S Normandie Ave, , Los Ángeles, CA 90007,...
# 370        NaN  450 Post Street, Union Square, San Francisco, ...
# 373        NaN  2015 Greenwich Street, Marina District, San Fr...
# 549        NaN  550 J Street, Centro de San Diego, San Diego, ...
# 1000       NaN  750 metros sur de Fórum 1 , 10901 San José, Co...
#
#                                             description attributes   latitude  \
# 0     El Central Los Angeles Hollywood Homes es un a...        NaN  34.038893
# 370   Este hotel del centro de San Francisco, rodead...        NaN  37.788249
# 373   El Motel Capri se encuentra en el distrito de ...        NaN  37.799194
# 549   Pendry San Diego se encuentra en San Diego, a ...        NaN  32.709395
# 1000  El Studio Hotel ofrece una piscina en la azote...        NaN   9.934250
#
#        longitude scores
# 0    -118.300133    NaN
# 370  -122.409400    NaN
# ...

# %%
df_atributos_california[df_atributos_california['attributes'].isnull()&df_atributos_california['description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %%
df_atributos_california[df_atributos_california['scores'].isnull()&df_atributos_california['description'].isnull()]
# Out:
#      hotel_id                                          direction description  \
# 833       NaN  1261 Bluebird Lane, La Jolla, San Diego, 92037...         NaN
#
#                                             attributes   latitude   longitude  \
# 833  ['Parking gratis', 'Microondas', 'Lavadora', '...  32.843949 -117.269678
#
#     scores
# 833    NaN

# %%
df_atributos_california[df_atributos_california['scores'].isnull()&df_atributos_california['description'].isnull()&df_atributos_california['attributes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %% [markdown]
# ## Analisis de atributos Florida

# %%
df_atributos_florida.shape
# Out:
# (1577, 7)

# %%
df_atributos_florida.head()
# Out:
#    hotel_id                                          direction  \
# 0        39  9204 Maybury Court, Tampa, FL 33615, Estados U...
# 1        78  3077 Tom Sawyer Drive, Kissimmee, 34746, Estad...
# 2        79  4373 Quote Street, Kissimmee, FL 34746, Estado...
# 3       221  3107 Sun Lake Court, Celebration, Orlando, FL ...
# 4       226                     Orlando, 32819, Estados Unidos
#
#                                          description  \
# 0  El Summertime Oasis - Tampa se encuentra en Ta...
# 1  El Thematic House w Pool in Resort w Clubhouse...
# 2  El 4BD Encanto home w/Free water park at Store...
# 3  El Mejor ubicacion y confort Best location & c...
# 4                                                NaN
#
#                                           attributes   latitude  longitude  \
# 0  ['Inglés', 'Preguntas frecuentes sobre el coro...  28.020441 -82.589648
# 1  ['Parking gratis', 'Servicio de lavandería', '...  28.340769 -81.477745
# ...

# %%
df_atributos_florida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1577 entries, 0 to 1576
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     1577 non-null   int64
#  1   direction    1577 non-null   object
#  2   description  1353 non-null   object
#  3   attributes   1104 non-null   object
#  4   latitude     1577 non-null   float64
#  5   longitude    1577 non-null   float64
#  6   scores       922 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 86.4+ KB

# %%
df_atributos_florida.describe()
# Out:
#            hotel_id     latitude    longitude
# count   1577.000000  1577.000000  1577.000000
# mean   23536.610653    27.939756   -81.924921
# std    13925.220593     1.360984     1.704905
# min       39.000000    25.770113   -87.178857
# 25%    11810.000000    26.600947   -82.008717
# 50%    23573.000000    28.279599   -81.600105
# 75%    36767.000000    28.380252   -81.446349
# max    43238.000000    30.489878   -80.119712

# %%
df_atributos_florida.isnull().sum()
# Out:
# hotel_id         0
# direction        0
# description    224
# attributes     473
# latitude         0
# longitude        0
# scores         655
# dtype: int64

# %%
df_atributos_florida['direction'].value_counts()
# Out:
# direction
# Pensacola Beach, 32561, Estados Unidos                                 90
# Kissimmee, 34747, Estados Unidos                                       32
# Kissimmee, 34746, Estados Unidos                                       30
# Cabo Coral, 33914, Estados Unidos                                      28
# Celebration, Orlando, FL 34747, Estados Unidos                         25
#                                                                        ..
# 6940 Westwood Boulevard, Orlando, FL 32821, Estados Unidos              1
# 5616 Major Boulevard, Orlando, FL 32819, Estados Unidos                 1
# 8000 Fins Up Circle, Celebration, Orlando, FL 34747, Estados Unidos     1
# 15836 Heron Hill Street, Orlando, FL 34714, Estados Unidos              1
# 2301 Collins Ave APT 337 , Miami Beach, 33139, Estados Unidos           1
# Name: count, Length: 1121, dtype: int64

# %% [markdown]
# ## Datos Nulos

# %%
sns.heatmap(df_atributos_florida.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atributos_florida[df_atributos_florida['attributes'].isnull()&df_atributos_florida['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 11         289                       Tampa, 33609, Estados Unidos
# 31         746  3012 Penelope Loop, Kissimmee, FL 34746, Estad...
# 113       3323  5225 Collins Avenue, Miami Beach, FL 33140, Es...
# 122       3528  2401 East Annie Street, Tampa, FL 33612, Estad...
# 141       4297  9011 Collins Ave, Miami Beach, FL 33154, Estad...
# ...        ...                                                ...
# 1551     43189  7660 Amazonas St, Celebration, Orlando, 34747,...
# 1557     43199  13415 Blue Heron Beach Drive 105, Lago Buena V...
# 1558     43200  1047 Clear Creek Circle, , Orlando, 34714, Est...
# 1565     43212  17319 Serenidad Boulevard, Orlando, FL 34714, ...
# 1571     43225   Celebration, Orlando, 34747-2122, Estados Unidos
#
#                                             description attributes   latitude  \
# 11    El Striking Getaway in Desirable Tampa Distric...        NaN  27.934740
# ...

# %%
df_atributos_florida[df_atributos_florida['description'].isnull()&df_atributos_florida['scores'].isnull()]
# Out:
#       hotel_id                                          direction description  \
# 26         608  4325 South Babcock Street 104, Melbourne, FL 3...         NaN
# 85        2051              Bonita Springs, 34134, Estados Unidos         NaN
# 128       4119  201 Ocean Avenue, Melbourne Beach, FL 32951, E...         NaN
# 145       4391  442 Cockatiel Drive, Jacksonville, FL 32225, E...         NaN
# 183       4953                   Kissimmee, 34746, Estados Unidos         NaN
# ...        ...                                                ...         ...
# 1531     43155  2813 Formosa Boulevard, Celebration, Orlando, ...         NaN
# 1532     43159                Jacksonville, 32210, Estados Unidos         NaN
# 1536     43165  1808 William Reggie Road, Cabo Coral, FL 33914...         NaN
# 1573     43230     Celebration, Orlando, FL 34747, Estados Unidos         NaN
# 1575     43236        Celebration, Orlando, 34747, Estados Unidos         NaN
#
# ...

# %%
df_atributos_florida[df_atributos_florida['attributes'].isnull()&df_atributos_florida['description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %%
df_atributos_florida[df_atributos_florida['attributes'].isnull()&df_atributos_florida['scores'].isnull()&df_atributos_florida['description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %% [markdown]
# ## Analisis de atributos Georgia

# %%
df_atributos_georgia.shape
# Out:
# (1402, 7)

# %%
df_atributos_georgia.head()
# Out:
#    hotel_id                                          direction  \
# 0         3  Peachtree Street Northeast, Atlanta, GA 30308,...
# 1        29  3205 Cumberland Boulevard Southeast 537, Atlan...
# 2       137  1700 Southwest 16 Court, Gainesville, 32608, E...
# 3       182  1429 Johns Road, Augusta, GA 30904, Estados Un...
# 4       190  2132 Drew Valley Road Northeast, Atlanta, GA 3...
#
#                                          description  \
# 0  El Modern Midtown Oasis se encuentra en Atlant...
# 1  El Beautiful 2 Bedroom 1 mile from Braves Stad...
# 2  El ConCrete Suite 5 Min Walk to Shands UF se e...
# 3                                                NaN
# 4  El Haven, recientemente renovado, se encuentra...
#
#                                           attributes   latitude  longitude  \
# 0  ['Gimnasio', 'Parking gratis', 'Barbacoa', 'Ha...  33.773452 -84.384421
# 1  ['Tipo de cocina\nAmericana', 'Gimnasio', 'Par...  33.877835 -84.462058
# ...

# %%
df_atributos_georgia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1402 entries, 0 to 1401
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     1402 non-null   int64
#  1   direction    1402 non-null   object
#  2   description  1241 non-null   object
#  3   attributes   1026 non-null   object
#  4   latitude     1402 non-null   float64
#  5   longitude    1402 non-null   float64
#  6   scores       813 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 76.8+ KB

# %%
df_atributos_georgia.describe()
# Out:
#            hotel_id     latitude    longitude
# count   1402.000000  1402.000000  1402.000000
# mean   22949.793866    35.959061   -42.039475
# std    13254.772832     3.577022    51.403819
# min        3.000000    29.601153   -84.622925
# 25%    11782.000000    33.747048   -84.348171
# 50%    22811.500000    33.953945   -82.027626
# 75%    34237.750000    37.978886    23.724447
# max    45528.000000    46.379341    23.819867

# %%
df_atributos_georgia.isnull().sum()
# Out:
# hotel_id         0
# direction        0
# description    161
# attributes     376
# latitude         0
# longitude        0
# scores         589
# dtype: int64

# %%
conteo_direction=df_atributos_georgia['direction'].value_counts()
conteo_mayor_que_1 = conteo_direction[conteo_direction > 1]
conteo_mayor_que_1
# Out:
# direction
# Savannah, 31401, Estados Unidos                                     16
# 215 Piedmont Avenue Northeast, Atlanta, GA 30308, Estados Unidos    16
# Piedmont Avenue Northeast 215, Atlanta, 30308, Estados Unidos       13
# 22 Rue de la République, 71000 Mâcon, Francia                        6
# Atlanta, 30309, Estados Unidos                                       6
#                                                                     ..
# 3332 Peachtree Road Northeast, Atlanta, GA 30326, Estados Unidos     2
# 4048 Morse Road, Columbus, OH 43230, Estados Unidos                  2
# 10, Ahilleos Str. Metaxourgio Square, Atenas, 104 36, Grecia         2
# 200 West Norwich Ave, Columbus, OH 43201, Estados Unidos             2
# 220 Margie Drive, Warner Robins, GA 31088, Estados Unidos            2
# Name: count, Length: 162, dtype: int64

# %% [markdown]
# ## Datos Nulos

# %%
sns.heatmap(df_atributos_georgia.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atributos_georgia[df_atributos_georgia['attributes'].isnull()&df_atributos_georgia['scores'].isnull()]
# Out:
#       hotel_id                                          direction  \
# 336      11632  3370 SW 42nd Street, Gainesville, 32608, Estad...
# 365      12460  127 Peachtree Street NE, Atlanta, GA 30303, Es...
# 413      13862  3300 Lenox Road, Atlanta, GA 30326, Estados Un...
# 420      14036  3300 Lenox Road, Atlanta, GA 30326, Estados Un...
# 457      15888                   33 Nileos, Atenas, 11851, Grecia
# ...        ...                                                ...
# 1165     37958  629 North West Frontage Road, Augusta, GA 3090...
# 1187     38818  7474 n high st, Columbus, OH 43235, Estados Un...
# 1191     38961  97 10th Street, Atlanta, GA 30309, Estados Unidos
# 1217     39959  215 Margie Drive, Warner Robins, GA 31088, Est...
# 1251     40855                     Atlanta, 30315, Estados Unidos
#
#                                             description attributes   latitude  \
# 336   El Holiday Inn Express & Suites - Gainesville ...        NaN  29.622215
# ...

# %%
df_atributos_georgia[df_atributos_georgia['description'].isnull()&df_atributos_georgia['scores'].isnull()]
# Out:
#       hotel_id                                          direction description  \
# 110       3668  969 Piedmont Avenue Northeast, Atlanta, GA 303...         NaN
# 127       3819   4 Πεισίστρατου, Kallithea, Atenas, 17674, Grecia         NaN
# 135       4030    26 Νηρέως, Palaio Faliro, Atenas, 17561, Grecia         NaN
# 203       6499                     Ermou 6, Atenas, 10563, Grecia         NaN
# 217       7763                    13 Πτώου, Atenas, 11741, Grecia         NaN
# ...        ...                                                ...         ...
# 1178     38425              Ploutarchou 28, Atenas, 10676, Grecia         NaN
# 1267     41376  7413 West Newberry Rd, Gainesville, FL 32605, ...         NaN
# 1289     42091  3378 Peachtree Road Northeast, Atlanta, GA 303...         NaN
# 1311     42956  5630 Wyncreek Circle, Atlanta, GA 30331, Estad...         NaN
# 1347     45442           Stone Mountain, GA 30083, Estados Unidos         NaN
#
# ...

# %%
df_atributos_georgia[df_atributos_georgia['description'].isnull()&df_atributos_georgia['attributes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %%
df_atributos_georgia[df_atributos_georgia['description'].isnull()&df_atributos_georgia['attributes'].isnull()&df_atributos_georgia['scores'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %% [markdown]
# ## Analisis de atributos Nevada

# %%
df_atributos_nevada.shape
# Out:
# (877, 8)

# %%
df_atributos_nevada.head()
# Out:
#    Unnamed: 0  hotel_id                                          direction  \
# 0           0       NaN  3850 Las Vegas Boulevard South, Las Vegas Stri...
# 1           1       NaN  75 East Harmon Avenue, Las Vegas Strip, Las Ve...
# 2           2       NaN  8335 Las Vegas Boulevard South, Las Vegas, NV ...
# 3           3       NaN  206 North 3rd Street , Las Vegas, NV 89101, Es...
# 4           4       NaN  3900 Las Vegas Boulevard South, Las Vegas Stri...
#
#                                          description  \
# 0  Este complejo y casino con temática de castill...
# 1  Situated 15 minutes' walk from the Las Vegas S...
# 2  El Hilton Vacation Club Cancun Resort Las Vega...
# 3  El Downtown Grand está ubicado en la zona de D...
# 4  El Luxor, famoso por su emblemática forma pira...
#
#                                           attributes   latitude   longitude  \
# 0  ['Parking en el alojamiento', 'WiFi', 'Spa y c...  36.100331 -115.173647
# ...

# %%
df_atributos_nevada = df_atributos_nevada.drop('Unnamed: 0', axis=1)

# %%
df_atributos_nevada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hotel_id     0 non-null      float64
#  1   direction    877 non-null    object
#  2   description  839 non-null    object
#  3   attributes   756 non-null    object
#  4   latitude     877 non-null    float64
#  5   longitude    877 non-null    float64
#  6   scores       747 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 48.1+ KB

# %%
df_atributos_nevada.describe()
# Out:
#        hotel_id    latitude   longitude
# count       0.0  877.000000  877.000000
# mean        NaN   16.039239    1.592404
# std         NaN   27.334632  117.285147
# min         NaN  -28.018201 -119.963729
# 25%         NaN  -27.993569 -115.171673
# 50%         NaN   35.996912  -73.817268
# 75%         NaN   36.165126  153.423878
# max         NaN   41.290371  153.432614

# %%
df_atributos_nevada.isnull().sum()
# Out:
# hotel_id       877
# direction        0
# description     38
# attributes     121
# latitude         0
# longitude        0
# scores         130
# dtype: int64

# %%
df_atributos_nevada['direction'].value_counts()
# Out:
# direction
# 9 Ferny Avenue, Surfers' Paradise, 4217 Gold Coast, Australia                   34
# Surfers' Paradise, 4217 Gold Coast, Australia                                   20
# 23 Ferny Avenue, Surfers' Paradise, 4217 Gold Coast, Australia                  17
# East Harmon Avenue 135, Las Vegas Strip, Las Vegas, 89109, Estados Unidos        9
# 125 East Harmon Avenue, Las Vegas Strip, Las Vegas, NV 89109, Estados Unidos     7
#                                                                                 ..
# 2 John Walsh Boulevard, Peekskill, NY 10566, Estados Unidos                      1
# Briarcliff Manor, 10510-2404, Estados Unidos                                     1
# 118 West Main Street, Elmsford, NY 10523, Estados Unidos                         1
# 119 South Highland Avenue, Ossining, NY 10562, Estados Unidos                    1
# 2421 Riviera Street, Reno, NV 89509, Estados Unidos                              1
# Name: count, Length: 613, dtype: int64

# %% [markdown]
# ## Datos Nulos

# %%
sns.heatmap(df_atributos_nevada.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df_atributos_nevada[df_atributos_nevada['attributes'].isnull()&df_atributos_nevada['scores'].isnull()]
# Out:
#      hotel_id                                          direction  \
# 607       NaN  22 View Avenue, Surfers' Paradise, 4217 Gold C...
# 656       NaN  25 Laycock Street, Surfers' Paradise, 4217 Gol...
# 664       NaN      Surfers' Paradise, 4217 Gold Coast, Australia
# 665       NaN  9 Ferny Avenue, Surfers' Paradise, 4217 Gold C...
# 711       NaN  19 Palm Avenue, Surfers' Paradise, 4217 Gold C...
# 718       NaN  23 Ferny Avenue, Surfers' Paradise, 4217 Gold ...
# 722       NaN  18 Hanlan Street, Surfers' Paradise, 4217 Gold...
# 725       NaN  24 Hamilton Avenue,Surfers Paradise, Surfers' ...
# 726       NaN  Unit 2905, Level 29, 5-19 Palm Avenue, Surfers...
# 754       NaN  23 Ferny Avenue, Surfers' Paradise, 4217 Gold ...
# 777       NaN  8 Thornton Street, Surfers' Paradise, 4217 Gol...
# 799       NaN  2940 Gold Coast Highway, Surfers' Paradise, 42...
# 812       NaN  200 Legends Bay Drive , Sparks, Reno, NV 89434...
# ...

# %%
df_atributos_nevada[df_atributos_nevada['description'].isnull()&df_atributos_nevada['scores'].isnull()]
# Out:
#      hotel_id                                          direction description  \
# 658       NaN  4 Adori Street, Surfers' Paradise, 4217 Gold C...         NaN
# 678       NaN  23 Ferny Avenue 2205, Surfers' Paradise, 4217 ...         NaN
# 685       NaN  6 View Avenue, Surfers' Paradise, 4217 Gold Co...         NaN
# 699       NaN  Orchid Avenue, Surfers' Paradise, 4217 Gold Co...         NaN
# 751       NaN  23 Ferny Avenue, Surfers' Paradise, 4217 Gold ...         NaN
# 769       NaN  3001/3440 Surfers Paradise Blvd , Surfers' Par...         NaN
# 829       NaN  1555 Victorian Avenue , Sparks, Reno, NV 89431...         NaN
# 868       NaN  636 N. Virginia St., Reno, NV 89501, Estados U...         NaN
#
#                                             attributes   latitude   longitude  \
# 658  ['Cafetera', 'Tostadora', 'Piscina al aire lib... -27.997774  153.421842
# 678  ['Barbacoa', 'WiFi gratis', '2 piscinas', 'Par... -27.999893  153.427390
# ...

# %%
df_atributos_nevada[df_atributos_nevada['description'].isnull()&df_atributos_nevada['attributes'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []

# %%
df_atributos_nevada[df_atributos_nevada['description'].isnull()&df_atributos_nevada['attributes'].isnull()&df_atributos_nevada['scores'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, direction, description, attributes, latitude, longitude, scores]
# Index: []
