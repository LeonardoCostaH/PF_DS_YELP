# %% [markdown]
# #### HOTELS ATTRIBUTES EXTRACTION PROCESS

# %% [markdown]
# This notebook was used to execute manually the scripts to scrape all of the previously scrapped hotels attributes.
#
# From the scrapping.py file we import scrape_hotels_attributes, this function takes a list of urls and returns a dataframe with the following hotel data:
#
# - attributes
# - scores
#
# The data was scrapped from the [Booking.com](https://www.booking.com/index.es.html?label=gen173nr-1BCAEoggI46AdIM1gEaAyIAQGYAQq4ARfIAQzYAQHoAQGIAgGoAgO4At_puqsGwAIB0gIkOTkxOTFjMmEtNTEzYS00NDQyLTgxNmMtMWJmMzMyYzVjNjJj2AIF4AIB&sid=1a3dea14733e69dc474ff74d1fad21e9&keep_landing=1&sb_price_type=total&) web, from a page like this: [boooking/hotels/newyork/hotel.com](https://www.booking.com/hotel/us/west-side-ymca.es.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaAyIAQGYAQq4ARfIAQzYAQHoAQH4AQyIAgGoAgO4Arj9uqsGwAIB0gIkMzNmMDQ2ZDMtOTkwYy00ZWVmLTgwZDYtYzhjMWUxZmFjM2Yz2AIG4AIB&sid=75f60e0ba4b489f2fe2baf48281729c2&dest_id=20088325;dest_type=city;dist=0;group_adults=2;group_children=0;hapos=4;hpos=4;no_rooms=1;req_adults=2;req_children=0;room1=A%2CA;sb_price_type=total;sr_order=popularity;srepoch=1701756621;srpvid=525f2b61586300dd;type=total;ucfs=1&#hotelTmpl).

# %%
import os
import sys
import scrapping
import pandas as pd

usa_cities = pd.read_csv("../files/data/usa_cities.csv")
usa_states = pd.read_csv("../files/data/usa_states.csv")
usa_hotels = pd.read_csv("../files/data/usa_hotels.csv", index_col=0)

# %%
# Diego
import os
import sys
import scrapping
import pandas as pd

usa_cities = pd.read_csv("../files/data/usa_cities.csv")
usa_states = pd.read_csv("../files/data/usa_states.csv")
usa_hotels = pd.read_csv("../files/data/booking/booking_hotels.csv", index_col=0)

# %% [markdown]
# California

# %%
california_hotels = usa_hotels[usa_hotels["state"] == "California"]
california_hotels_url_list = california_hotels["reviews_url"].tolist()
california_hotels_ids_list = california_hotels["hotel_id"].tolist()

# %%
california_hotels_attributes_1_3 = scrapping.scrape_hotels_attributes(california_hotels_url_list[:500], california_hotels_ids_list[:500])
california_hotels_attributes_1_3.to_csv("../files/data/booking/attributes/california_hotels_attributes_1_3.csv")
california_hotels_attributes_1_3
# Out:
# 1/500
# c:\Users\david\Documents\GitHub\PF_DS_YELP\scrapping\scrapping.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   hotels_attributes = pd.concat([hotels_attributes, attributes], ignore_index=True, sort=False)
# 2/500
# 3/500
# 4/500
# 5/500
# 6/500
# 7/500
# 8/500
# 9/500
# 10/500
# 11/500
# 12/500
# Error StaleElementReferenceException obteniendo scores para el hotel con ID 351
# 13/500
# 14/500
# 15/500
# 16/500
# 17/500
# 18/500
# 19/500
# 20/500
# Error StaleElementReferenceException obteniendo scores para el hotel con ID 592
# 21/500
# 22/500
# 23/500
# 24/500
# 25/500
# 26/500
# 27/500
# 28/500
# 29/500
# 30/500
# 31/500
# 32/500
# 33/500
# 34/500
# 35/500
# 36/500
# 37/500
# 38/500
# 39/500
# 40/500
# 41/500
# 42/500
# ...

# %%
california_hotels_attributes_2_3 = scrapping.scrape_hotels_attributes(california_hotels_url_list[500:1000], california_hotels_ids_list[500:1000])
california_hotels_attributes_2_3.to_csv("../files/data/booking/attributes/california_hotels_attributes_2_3.csv")
california_hotels_attributes_2_3
# Out:
# 1/500
# c:\Users\david\Documents\GitHub\PF_DS_YELP\scrapping\scrapping.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   hotels_attributes = pd.concat([hotels_attributes, attributes], ignore_index=True, sort=False)
# 2/500
# 3/500
# 4/500
# 5/500
# 6/500
# 7/500
# 8/500
# 9/500
# 10/500
# Error StaleElementReferenceException obteniendo scores para el hotel con ID 15429
# 11/500
# 12/500
# 13/500
# 14/500
# Error StaleElementReferenceException obteniendo scores para el hotel con ID 15458
# 15/500
# 16/500
# 17/500
# 18/500
# 19/500
# 20/500
# 21/500
# 22/500
# Error StaleElementReferenceException obteniendo scores para el hotel con ID 15531
# 23/500
# 24/500
# 25/500
# 26/500
# 27/500
# 28/500
# 29/500
# 30/500
# ...

# %%
california_hotels_attributes_3_3 = scrapping.scrape_hotels_attributes(california_hotels_url_list[1000:], california_hotels_ids_list[1000:])
california_hotels_attributes_3_3.to_csv("../files/data/booking/attributes/california_hotels_attributes_3_3.csv")
california_hotels_attributes_3_3
# Out:
# 1/556
# c:\Users\david\Documents\GitHub\PF_DS_YELP\scrapping\scrapping.py:273: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   hotels_attributes = pd.concat([hotels_attributes, attributes], ignore_index=True, sort=False)
# 2/556
# 3/556
# 4/556
# 5/556
# 6/556
# 7/556
# 8/556
# 9/556
# 10/556
# 11/556
# 12/556
# 13/556
# 14/556
# 15/556
# 16/556
# 17/556
# 18/556
# 19/556
# 20/556
# 21/556
# 22/556
# 23/556
# 24/556
# 25/556
# 26/556
# 27/556
# 28/556
# 29/556
# 30/556
# 31/556
# 32/556
# 33/556
# 34/556
# 35/556
# 36/556
# 37/556
# 38/556
# 39/556
# 40/556
# 41/556
# 42/556
# 43/556
# 44/556
# 45/556
# 46/556
# 47/556
# 48/556
# 49/556
# 50/556
# 51/556
# 52/556
# 53/556
# 54/556
# 55/556
# 56/556
# 57/556
# 58/556
# 59/556
# 60/556
# ...

# %%
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/california_hotels_attributes_3_3.csv", index_col=0)

# %%
attributes_1_3 = pd.read_csv("../files/data/booking/attributes/california_hotels_attributes_1_3.csv", index_col=0)
attributes_2_3 = pd.read_csv("../files/data/booking/attributes/california_hotels_attributes_2_3.csv", index_col=0)
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/california_hotels_attributes_3_3.csv", index_col=0)
california_hotels_attributes = pd.concat([attributes_1_3, attributes_2_3, attributes_3_3], ignore_index=True)
os.remove("../files/data/booking/attributes/california_hotels_attributes_1_3.csv")
os.remove("../files/data/booking/attributes/california_hotels_attributes_2_3.csv")
os.remove("../files/data/booking/attributes/california_hotels_attributes_3_3.csv")
california_hotels_attributes.to_csv("../files/data/booking/attributes/california_hotels_attributes.csv")
# Out:
#       Unnamed: 0  hotel_id                                          direction  \
# 0              0        16  24232 Tahoe Court, Laguna Niguel, CA 92677, Es...
# 1              1        27  220 20th Street, Newport Beach, CA 92663, Esta...
# 2              2        35  Pacific Beach, San Diego, 92109-5890, Estados ...
# 3              3        39  Julian Avenue 2054, San Diego, 92113, Estados ...
# 4              4        44  4050 Albatross Street, Unit 4048, Hillcrest, S...
# ...          ...       ...                                                ...
# 1551         551     36697  2044 N Sycamore Ave , Hollywood, Los Ángeles, ...
# 1552         552     36703  3 Paseo Vespertino, Rancho Santa Margarita, CA...
# 1553         553     36710      25 Pacifica, Irvine, CA 92618, Estados Unidos
# 1554         554     36713  31861 Coast Highway, Laguna Beach, CA 92651, E...
# 1555         555     36716  2428 Glyndon Avenue, Venice Beach, Los Ángeles...
#
# ...

# %% [markdown]
# ### Nevada

# %%
nevada_hotels = usa_hotels[usa_hotels["state"] == "Nevada"]
nevada_hotels_url_list = nevada_hotels["reviews_url"].tolist()
nevada_hotels_ids_list = nevada_hotels["hotel_id"].tolist()

# %%
nevada_hotels
# Out:
#         state             city                                           name  \
# 27573  Nevada  North Las Vegas     The Goat Hut Studio Casita 11 Mi to Strip!
# 28037  Nevada         Paradise           Amazing Water Views Surfers Paradise
# 27942  Nevada    Sunrise Manor     London Studio apartment @hiranandani thane
# 28162  Nevada           Sparks                                Cul-De-Sac Home
# 27468  Nevada        Las Vegas     The Goat Hut Studio Casita 11 Mi to Strip!
# ...       ...              ...                                            ...
# 27851  Nevada    Sunrise Manor     Super Big 3 BHK, near Station with parking
# 27916  Nevada    Sunrise Manor                      Cairo studio @hiranandani
# 27915  Nevada    Sunrise Manor                       Hotel Welcome Inn,Mumbai
# 27886  Nevada    Sunrise Manor                   OYO Flagship Hotel Plaza Inn
# 27898  Nevada    Sunrise Manor  Wind Flower Regency - Near Kokilaben Hospital
#
# ...

# %%
nevada_hotels_attributes_1_3 = scrapping.scrape_hotels_attributes(nevada_hotels_url_list[:250], nevada_hotels_ids_list[:250])
nevada_hotels_attributes_1_3.to_csv("../files/data/booking/attributes/nevada_hotels_attributes_1_3.csv")
nevada_hotels_attributes_1_3
# Out:
# 1/250
# 2/250
# Error obteniendo atributos para el hotel con ID 248: Message: stale element reference: stale element not found
#   (Session info: chrome=119.0.6045.200); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF64F1F82B2+55298]
# 	(No symbol) [0x00007FF64F165E02]
# 	(No symbol) [0x00007FF64F0205AB]
# 	(No symbol) [0x00007FF64F02509C]
# 	(No symbol) [0x00007FF64F026FDF]
# 	(No symbol) [0x00007FF64F0270D0]
# 	(No symbol) [0x00007FF64F05CDFE]
# 	(No symbol) [0x00007FF64F0820AA]
# 	(No symbol) [0x00007FF64F0580CF]
# 	(No symbol) [0x00007FF64F0822C0]
# 	(No symbol) [0x00007FF64F09AAA4]
# 	(No symbol) [0x00007FF64F081E83]
# 	(No symbol) [0x00007FF64F05670A]
# 	(No symbol) [0x00007FF64F057964]
# 	GetHandleVerifier [0x00007FF64F570AAB+3694587]
# 	GetHandleVerifier [0x00007FF64F5C728E+4048862]
# ...

# %%
nevada_hotels_attributes_2_3 = scrapping.scrape_hotels_attributes(nevada_hotels_url_list[250:500], nevada_hotels_ids_list[250:500])
nevada_hotels_attributes_2_3.to_csv("../files/data/booking/attributes/nevada_hotels_attributes_2_3.csv")
nevada_hotels_attributes_2_3
# Out:
# 1/250
# 2/250
# 3/250
# Error obteniendo atributos para el hotel con ID 18510: Message: stale element reference: stale element not found
#   (Session info: chrome=119.0.6045.200); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF64F1F82B2+55298]
# 	(No symbol) [0x00007FF64F165E02]
# 	(No symbol) [0x00007FF64F0205AB]
# 	(No symbol) [0x00007FF64F02509C]
# 	(No symbol) [0x00007FF64F026FDF]
# 	(No symbol) [0x00007FF64F0270D0]
# 	(No symbol) [0x00007FF64F05CDFE]
# 	(No symbol) [0x00007FF64F0820AA]
# 	(No symbol) [0x00007FF64F0580CF]
# 	(No symbol) [0x00007FF64F0822C0]
# 	(No symbol) [0x00007FF64F09AAA4]
# 	(No symbol) [0x00007FF64F081E83]
# 	(No symbol) [0x00007FF64F05670A]
# 	(No symbol) [0x00007FF64F057964]
# 	GetHandleVerifier [0x00007FF64F570AAB+3694587]
# 	GetHandleVerifier [0x00007FF64F5C728E+4048862]
# ...

# %%
nevada_hotels_attributes_3_3 = scrapping.scrape_hotels_attributes(nevada_hotels_url_list[500:], nevada_hotels_ids_list[500:])
nevada_hotels_attributes_3_3.to_csv("../files/data/booking/attributes/nevada_hotels_attributes_3_3.csv")
nevada_hotels_attributes_3_3
# Out:
# 1/280
# 2/280
# 3/280
# 4/280
# 5/280
# 6/280
# 7/280
# 8/280
# 9/280
# 10/280
# 11/280
# Error obteniendo descripción para el hotel con ID 29514: Message: stale element reference: stale element not found
#   (Session info: chrome=119.0.6045.200); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF64F1F82B2+55298]
# 	(No symbol) [0x00007FF64F165E02]
# 	(No symbol) [0x00007FF64F0205AB]
# 	(No symbol) [0x00007FF64F02509C]
# 	(No symbol) [0x00007FF64F026FDF]
# 	(No symbol) [0x00007FF64F0270D0]
# 	(No symbol) [0x00007FF64F05CDFE]
# 	(No symbol) [0x00007FF64F0820AA]
# 	(No symbol) [0x00007FF64F0580CF]
# 	(No symbol) [0x00007FF64F0822C0]
# 	(No symbol) [0x00007FF64F09AAA4]
# 	(No symbol) [0x00007FF64F081E83]
# 	(No symbol) [0x00007FF64F05670A]
# 	(No symbol) [0x00007FF64F057964]
# 	GetHandleVerifier [0x00007FF64F570AAB+3694587]
# ...

# %%
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/nevada_hotels_attributes_3_3.csv", index_col=0)

# %%
attributes_1_3 = pd.read_csv("../files/data/booking/attributes/nevada_hotels_attributes_1_3.csv", index_col=0)
attributes_2_3 = pd.read_csv("../files/data/booking/attributes/nevada_hotels_attributes_2_3.csv", index_col=0)
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/nevada_hotels_attributes_3_3.csv", index_col=0)
nevada_hotels_attributes = pd.concat([attributes_1_3, attributes_2_3, attributes_3_3], ignore_index=True)
os.remove("../files/data/booking/attributes/nevada_hotels_attributes_1_3.csv")
os.remove("../files/data/booking/attributes/nevada_hotels_attributes_2_3.csv")
os.remove("../files/data/booking/attributes/nevada_hotels_attributes_3_3.csv")
nevada_hotels_attributes.to_csv("../files/data/booking/attributes/nevada_hotels_attributes.csv")

# %%
# filas donde 'direction' contiene la palabra 'india'
filtered_df = nevada_hotels_attributes[nevada_hotels_attributes['direction'].str.contains('india', case=False, na=False)]

# %%
filtered_df
# Out:
#      hotel_id                                          direction  \
# 2         257       Hiranandani Estate Road, 400607 Thane, India
# 14        802  Amber CHS, Suresh Nagar SRA CHS, RTO Rd, near ...
# 21       2164  7th Floor, Velankanni Heights, St Braz Road, B...
# 43       3046             2-202 Panch Marg, 400061 Bombay, India
# 46       3158  Chaul no - 8B, Bandra beach view society, Chim...
# ..        ...                                                ...
# 775     39317  Meenatai Thakrey Chowk Tejadeep Heights, G Win...
# 776     39423                Arcadia Circle, 400607 Thane, India
# 777     39436  F N 17 RN 1 NSS ROAD ASLPHA OPP DISHA HOSPITAL...
# 778     39587  Plot B/24, Vande Mataram Hotel, Sarveshvar Man...
# 779     39630                   Mhada Road, 400053 Bombay, India
#
#                                            description  \
# 2    London Studio apartment @hiranandani thane est...
# 14   Cozy AC Studio W/ Kitchenette Nr Kokilaben Hos...
# ...

# %% [markdown]
# ### Oregon

# %%
oregon_hotels = usa_hotels[usa_hotels["state"] == "Oregon"]
oregon_hotels_url_list = oregon_hotels["reviews_url"].tolist()
oregon_hotels_ids_list = oregon_hotels["hotel_id"].tolist()

# %%
oregon_hotels
# Out:
# Empty DataFrame
# Columns: [state, city, name, avg_score, price, reviews_url, hotel_id]
# Index: []

# %%
oregon_hotels_attributes_1_3 = scrapping.scrape_hotels_attributes(oregon_hotels_url_list[:500], oregon_hotels_ids_list[:500])
oregon_hotels_attributes_1_3.to_csv("../files/data/booking/attributes/oregon_hotels_attributes_1_3.csv")
oregon_hotels_attributes_1_3

# %%
oregon_hotels_attributes_2_3 = scrapping.scrape_hotels_attributes(oregon_hotels_url_list[500:1000], oregon_hotels_ids_list[500:1000])
oregon_hotels_attributes_2_3.to_csv("../files/data/booking/attributes/oregon_hotels_attributes_2_3.csv")
oregon_hotels_attributes_2_3

# %%
oregon_hotels_attributes_3_3 = scrapping.scrape_hotels_attributes(oregon_hotels_url_list[1000:], oregon_hotels_ids_list[1000:])
oregon_hotels_attributes_3_3.to_csv("../files/data/booking/attributes/oregon_hotels_attributes_3_3.csv")
oregon_hotels_attributes_3_3

# %%
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/oregon_hotels_attributes_3_3.csv", index_col=0)

# %%
attributes_1_3 = pd.read_csv("../files/data/booking/attributes/oregon_hotels_attributes_1_3.csv", index_col=0)
attributes_2_3 = pd.read_csv("../files/data/booking/attributes/oregon_hotels_attributes_2_3.csv", index_col=0)
attributes_3_3 = pd.read_csv("../files/data/booking/attributes/oregon_hotels_attributes_3_3.csv", index_col=0)
oregon_hotels_attributes = pd.concat([attributes_1_3, attributes_2_3, attributes_3_3], ignore_index=True)
os.remove("../files/data/booking/attributes/oregon_hotels_attributes_1_3.csv")
os.remove("../files/data/booking/attributes/oregon_hotels_attributes_2_3.csv")
os.remove("../files/data/booking/attributes/oregon_hotels_attributes_3_3.csv")
oregon_hotels_attributes.to_csv("../files/data/booking/attributes/oregon_hotels_attributes.csv")
