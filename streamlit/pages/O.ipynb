# %%
import ast
import pandas as pd

hotel_attributes = pd.read_csv("../../files/data/booking/california_hotels_attributes.csv", index_col=0)
hotel_attributes['Scores'] = hotel_attributes['Scores'].apply(ast.literal_eval)
hotel_attributes
# Out:
#                                               Dirección  \
# 0     1418 Butler Avenue, Los Ángeles, CA 90025, Est...
# 1     6101 West Century Boulevard, Los Ángeles, CA 9...
# 2     2011 North Highland Avenue, Hollywood, Los Áng...
# 3     6516 W Selma Ave, Hollywood, Los Ángeles, 9002...
# 4     1400 Cahuenga Boulevard, Hollywood, Los Ángele...
# ...                                                 ...
# 1541  1035 Hipólito Yrigoyen PB 1, 3200 Concordia, A...
# 1542           1190 San Luis, 3200 Concordia, Argentina
# 1543            421 Honduras, 3201 Concordia, Argentina
# 1544    República del Brasil, 3200 Concordia, Argentina
# 1545                39 Mitre, 3200 Concordia, Argentina
#
#                                             Descripción  \
# 0     El Executive Santa Monica Suites se encuentra ...
# 1     Este hotel moderno proporciona un servicio exc...
# 2     Este hotel, situado a solo 2 calles de la aven...
# 3     El tommie Hollywood, part of Jdv by Hyatt se e...
# ...

# %%
for i, row in hotel_attributes.iterrows():
    print(row["Scores"])
# Out:
# [{'Personal': '8.8'}, {'Instalaciones y servicios': '8.5'}, {'Limpieza': '8.5'}, {'Confort': '8.4'}, {'Relación calidad-precio': '8.0'}, {'Ubicación': '8.8'}, {'WiFi gratis': '9.8'}]
# ...
