# %%
import pandas as pd

usa_cities = pd.read_csv("../../files/data/usa_cities.csv")
usa_states = pd.read_csv("../../files/data/usa_states.csv", index_col=0)
usa_attractions = pd.read_csv("../../files/data/usa_attractions.csv", index_col=0)
booking_hotels = pd.read_csv("../../files/data/booking/booking_hotels.csv", index_col=0)
clients_reviews = pd.read_csv("../../files/data/usa_clients_reviews.csv", index_col=0)
usa_clients = pd.read_csv("../../files/data/usa_clients.csv", index_col=0)
usa_attractions
# Out:
#                   region     state                     attraction  n_reviews  \
# 0     East North Central  Illinois   Instituto de Arte de Chicago     24.543
# 1     East North Central  Illinois              Parque Millennium     25.133
# 2     East North Central  Illinois   Museo de Ciencia e Industria     11.184
# 3     East North Central  Illinois                     Cloud Gate     18.279
# 4     East North Central  Illinois           The Magnificent Mile     15.799
# ...                  ...       ...                            ...        ...
# 4017  West South Central     Texas            Time Crunch Escapes    211.000
# 4018  West South Central     Texas       Galveston Shuttle & Limo    441.000
# 4019  West South Central     Texas              Waco Escape Rooms    614.000
# 4020  West South Central     Texas  Escapology Escape Rooms Tyler    310.000
# 4021  West South Central     Texas               Fun Dallas Tours      2.065
#
# ...

# %%
hotels_by_city = booking_hotels.groupby("city")["name"].count()
hotels_by_city
# Out:
# city
# Aberdeen        65
# Akron           47
# Albany          48
# Albuquerque     76
# Alexandria     155
#               ...
# Woonsocket      39
# Worcester       90
# Yonkers        284
# York           240
# Youngstown      47
# Name: name, Length: 399, dtype: int64

# %%
import plotly.express as px

# Mapa de ciudades
fig_cities = px.scatter_geo(
    usa_cities,
    lat="latitude",
    lon="longitude",
    size="population",
    #text="city",
    title="Ciudades en Estados Unidos",
    scope="usa"
)

fig_cities.show()

# %% [markdown]
# ### visualization

# %%
import numpy as np
import pandas as pd
import plotly.express as px

client_reviews = pd.read_csv("../../files/data/usa_clients_reviews.csv", index_col=0)
client_reviews
# Out:
#          nationality                                       acommodation  stay  \
# 2      Corea del Sur  Suite Estudio con cocina y sofá cama - Cama ex...  27.0
# 3             Taiwán                             Den Room with King Bed   4.0
# 4     Estados Unidos  Suite Estudio con cocina y sofá cama - Cama ex...   4.0
# 5     Estados Unidos  Suite con 1 dormitorio, cama extragrande, sofá...   6.0
# 6     Estados Unidos  Suite con 1 dormitorio, cama extragrande, sofá...   1.0
# ...              ...                                                ...   ...
# 1960  Estados Unidos                   Habitación con cama extragrande.   1.0
# 1961          Suecia                   Habitación con cama extragrande.   6.0
# 1962   Corea del Sur                   Habitación con cama extragrande.   4.0
# 1963   San Bartolomé                   Habitación con cama extragrande.   2.0
# 1964           Japón                   Habitación con cama extragrande.   7.0
#
#                      company  \
# ...

# %%
fig = px.scatter(client_reviews, x="date", y="sentiment",
                 color='sentiment',
                 #labels={"sentiment": "Sentimiento de la Reseña"},
                 height=900)

# Mostrar la figura
fig.show()

# %%
# Crear el Violin Plot con Plotly Express
fig = px.violin(client_reviews, x='company', y='sentiment', #color='', #points="all",
                title="Violin Plot de dos grupos",
                labels={"Value": "Valor", "Category": "Grupo"},
                violinmode="overlay",  # "overlay" para superponer
                box=False,  # No mostrar la caja
                height=900,  # Altura del gráfico
                width=1600
                )  # Ancho del gráfico

# Mostrar la figura
fig.show()

# %%
import plotly.express as px
reviews = pd.read_csv("../../files/data/booking/review.csv", index_col=0)
reviews
# Out:
#         nationality                                       acommodation  \
# 0            España  Habitación con bañera adaptada para personas c...
# 1             Chile  Habitación Doble con balcón y vistas a la bahí...
# 2            México                   Habitación con cama extragrande.
# 3            México  Habitación Doble con balcón y vistas a la bahí...
# 4            España                     Habitación con 2 camas grandes
# ..              ...                                                ...
# 434          México             Habitación Deluxe con cama extragrande
# 435           Rusia                   Habitación con cama extragrande.
# 436          Grecia             Habitación Deluxe con cama extragrande
# 437  Estados Unidos                  Habitación Doble - 2 camas dobles
# 438  Estados Unidos                  Habitación Doble - 2 camas dobles
#
#          stay     company                         review_title  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\david\Documents\GitHub\PF_DS_YELP\streamlit\pages\streamlit.ipynb Celda 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/david/Documents/GitHub/PF_DS_YELP/streamlit/pages/streamlit.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> # Crear el Violin Plot con solo los puntos
# ----> <a href='vscode-notebook-cell:/c%3A/Users/david/Documents/GitHub/PF_DS_YELP/streamlit/pages/streamlit.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> fig = px.scatter(reviews, x="month", y="sentiment",
#       <a href='vscode-notebook-cell:/c%3A/Users/david/Documents/GitHub/PF_DS_YELP/streamlit/pages/streamlit.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a>                  color='is_american',
# ...
